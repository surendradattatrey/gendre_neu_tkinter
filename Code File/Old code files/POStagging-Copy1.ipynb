# %%
import random
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize 
import numpy
import pandas as pd

nltk.download('tagsets')
nltk.download('brown')

gender_score = pd.read_csv (r'C:/Users/surendra_dattatrey/Desktop/S&P Data/Gender Neutral JD/POS_gender_score.csv')

Job_details = pd.read_csv ('C:/Users/surendra_dattatrey/Desktop/S&P Data/Gender Neutral JD/JD_detail.csv', encoding='cp1252')
# Out:
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\surendra_dattatrey\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\surendra_dattatrey\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package brown is already up-to-date!

# %%
Job_details['Job Description_tokenized'] = Job_details['Job Description'].apply(word_tokenize)

# %%
word_lst = Job_details['Job Description_tokenized'].values.tolist()
# Out:
# [['The',
#   'Team',
#   ':',
#   'He',
#   'is',
#   'responsible',
#   'for',
#   'executing',
#   'Data',
#   'Science',
#   'projects',
#   'end',
#   'to',
#   'end',
#   '.',
#   'The',
#   'project',
#   'list',
#   'includes',
#   '(',
#   'but',
#   'is',
#   'not',
#   'limited',
#   'to',
#   ')',
#   'Recommendation',
#   'Engines',
#   ',',
#   'NLP',
#   'Based',
#   'Classifiers',
#   ',',
#   'Ratings',
#   'Prediction',
#   ',',
#   'Bond',
#   'Scoring',
#   ',',
#   'Bond',
#   'Issuance',
#   'etc',
#   'The',
#   'Impact',
#   ':',
#   'This',
#   'is',
#   'a',
#   'key',
#   'position',
#   'in',
#   'the',
#   'team',
#   'that',
#   'would',
#   'ensure',
#   'data',
#   'readiness',
#   'for',
#   'some',
#   'of',
#   'our',
#   'key',
#   'projects',
#   'in',
#   'Markets',
#   'Intelligence',
#   'division',
#   'that',
#   'would',
#   'have',
#   'substantial',
#   'impact',
#   'on',
#   'an',
#   'upcoming',
#   'product',
#   '.',
#   'What',
#   '’',
#   's',
#   'in',
#   'it',
#   'for',
#   'you',
#   ':',
#   'You',
#   'will',
#   'further',
#   'fortify',
#   'your',
#   'skills',
#   'as',
#   'a',
#   'Data',
#   'Engineer',
#   'while',
#   'gaining',
#   'perspective',
#   'in',
#   'Predictive',
#   'Analytics',
#   '.',
#   'The',
#   'role',
#   'shall',
#   'help',
#   'you',
#   'grow',
#   'in',
#   'following',
#   'areas',
#   ':',
#   '•Big',
#   'Data/Cloud',
#   'Technology',
#   'based',
#   'Analytics',
#   '•Introduce',
#   'you',
#   'to',
#   'and',
#   'guide',
#   'you',
#   'on',
#   'cutting',
#   'edge',
#   'Machine',
#   'Learning',
#   'techniques',
#   '•Encourage',
#   'you',
#   'to',
#   'bring',
#   'in',
#   'new',
#   'ideas',
#   'and',
#   'provide',
#   'you',
#   'means',
#   'to',
#   'learn/implement',
#   'them',
#   'to',
#   'fulfill',
#   'project',
#   'needs',
#   'Responsibilities',
#   ':',
#   'The',
#   'key',
#   'responsibility',
#   'of',
#   'the',
#   'data',
#   'engineer',
#   'is',
#   'to',
#   'ingest',
#   'structured',
#   ',',
#   'semi',
#   'structured',
#   'and',
#   'unstructured',
#   'data',
#   'from',
#   'across',
#   'the',
#   'whole',
#   'organization',
#   'within',
#   'planned',
#   'timeframes',
#   'for',
#   'the',
#   'team',
#   'of',
#   'data',
#   'scientists',
#   'to',
#   'analyze',
#   ',',
#   'build',
#   'models',
#   'and',
#   'solutions',
#   'for',
#   'the',
#   'different',
#   'S',
#   '&',
#   'P',
#   'businesses',
#   '.',
#   'As',
#   'such',
#   ',',
#   'the',
#   'data',
#   'engineer',
#   'will',
#   'work',
#   'with',
#   'Stakeholders',
#   ',',
#   'Business',
#   'Users',
#   'and',
#   'Data',
#   'Scientists',
#   'to',
#   'understand',
#   'the',
#   'business',
#   'goals',
#   'and',
#   'requirements',
#   'and',
#   'translate',
#   'them',
#   'into',
#   'data',
#   'requirements',
#   '.',
#   'The',
#   'engineer',
#   'will',
#   'design',
#   'and',
#   'build',
#   'efficient',
#   'data',
#   'extraction/processing/storage',
#   'logic',
#   'from/to',
#   'Databases',
#   ',',
#   'cloud',
#   'systems',
#   ',',
#   'Big',
#   'Data',
#   ',',
#   'Restful',
#   'APIs',
#   'etc',
#   '.',
#   'The',
#   'role',
#   'also',
#   'involves',
#   'architecting',
#   'and',
#   'developing',
#   'end',
#   'to',
#   'end',
#   'data',
#   'pipelines',
#   'to',
#   'help',
#   'solve',
#   'data',
#   'science',
#   'problems',
#   'while',
#   'also',
#   'engaging',
#   'in',
#   'overall',
#   'project',
#   'development',
#   'activities',
#   '.',
#   'What',
#   'We',
#   '’',
#   're',
#   'Looking',
#   'For',
#   ':',
#   'Basic',
#   'Qualifications',
#   ':',
#   '•Bachelor',
#   '’',
#   's',
#   'degree',
#   'in',
#   'engineering',
#   '.',
#   '•Minimum',
#   'of',
#   '7',
#   'years',
#   'of',
#   'experience',
#   'in',
#   'Data',
#   'Engineering',
#   '•Experience',
#   'in',
#   'dealing',
#   'with',
#   'servers',
#   ',',
#   'production',
#   'systems',
#   ',',
#   'multiple',
#   'environments',
#   'and',
#   'varied',
#   'software',
#   'engineering',
#   'aspects',
#   '•Knowledge',
#   'of',
#   'Data',
#   'Profiling',
#   'and',
#   'Data',
#   'Quality',
#   'concepts',
#   'and',
#   'techniques',
#   '•Ability',
#   'to',
#   'work',
#   'independently',
#   'and',
#   'achieve',
#   'expected',
#   'results',
#   'with',
#   'general/broad',
#   'level',
#   'requirements',
#   '•Strong',
#   'written',
#   '&',
#   'verbal',
#   'communication',
#   '•Python',
#   'and/or',
#   'R',
#   '•SQL',
#   '•Operability',
#   'in',
#   'Unix/Linux',
#   '•ETL',
#   'Tools',
#   'and',
#   'Data',
#   'Warehousing',
#   '•Big',
#   'Data',
#   '(',
#   'atleast',
#   '3',
#   ')',
#   '–',
#   'Hive',
#   ',',
#   'HDFS',
#   ',',
#   'Flume',
#   ',',
#   'Kafka',
#   ',',
#   'NoSQL',
#   '(',
#   'HBase/MongoDB',
#   'etc',
#   ')',
#   ',',
#   'Spark/PySpark',
#   ',',
#   'Cloud',
#   'Technologies',
#   'Preferred',
#   'Qualifications',
#   ':',
#   '•Familiarity',
#   'with',
#   'RESTful',
#   'APIs',
#   '•Initial',
#   'exposure',
#   'to',
#   'machine',
#   'learning',
#   'is',
#   'good',
#   'to',
#   'have']]

# %%
word_list=[]
for i in range(len(word_lst)):
    word_list.append([])
for i in range(len(word_lst)): 
    for word in word_lst[i]:
        if word[1:].isalpha():
            word_list[i].append(word[0:])

# %%
tagged_tokens=[]
for token in word_list:
    tagged_tokens.append(nltk.pos_tag(token))

# %%
import itertools
merged = list(itertools.chain(*tagged_tokens))
# Out:
# [('The', 'DT'),
#  ('Team', 'NN'),
#  ('He', 'PRP'),
#  ('is', 'VBZ'),
#  ('responsible', 'JJ'),
#  ('for', 'IN'),
#  ('executing', 'VBG'),
#  ('Data', 'NNP'),
#  ('Science', 'NNP'),
#  ('projects', 'NNS'),
#  ('end', 'VBP'),
#  ('to', 'TO'),
#  ('end', 'VB'),
#  ('The', 'DT'),
#  ('project', 'NN'),
#  ('list', 'NN'),
#  ('includes', 'VBZ'),
#  ('but', 'CC'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('limited', 'VBN'),
#  ('to', 'TO'),
#  ('Recommendation', 'NNP'),
#  ('Engines', 'NNP'),
#  ('NLP', 'NNP'),
#  ('Based', 'VBD'),
#  ('Classifiers', 'NNP'),
#  ('Ratings', 'NNP'),
#  ('Prediction', 'NNP'),
#  ('Bond', 'NNP'),
#  ('Scoring', 'NNP'),
#  ('Bond', 'NNP'),
#  ('Issuance', 'NNP'),
#  ('etc', 'VBD'),
#  ('The', 'DT'),
#  ('Impact', 'NNP'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('key', 'JJ'),
#  ('position', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('team', 'NN'),
#  ('that', 'WDT'),
#  ('would', 'MD'),
#  ('ensure', 'VB'),
#  ('data', 'NNS'),
#  ('readiness', 'NN'),
#  ('for', 'IN'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('key', 'JJ'),
#  ('projects', 'NNS'),
#  ('in', 'IN'),
#  ('Markets', 'NNP'),
#  ('Intelligence', 'NNP'),
#  ('division', 'NN'),
#  ('that', 'WDT'),
#  ('would', 'MD'),
#  ('have', 'VB'),
#  ('substantial', 'JJ'),
#  ('impact', 'NN'),
#  ('on', 'IN'),
#  ('an', 'DT'),
#  ('upcoming', 'JJ'),
#  ('product', 'NN'),
#  ('What', 'WP'),
#  ('in', 'IN'),
#  ('it', 'PRP'),
#  ('for', 'IN'),
#  ('you', 'PRP'),
#  ('You', 'PRP'),
#  ('will', 'MD'),
#  ('further', 'VB'),
#  ('fortify', 'VB'),
#  ('your', 'PRP$'),
#  ('skills', 'NNS'),
#  ('as', 'IN'),
#  ('Data', 'NNP'),
#  ('Engineer', 'NNP'),
#  ('while', 'IN'),
#  ('gaining', 'VBG'),
#  ('perspective', 'NN'),
#  ('in', 'IN'),
#  ('Predictive', 'NNP'),
#  ('Analytics', 'NNPS'),
#  ('The', 'DT'),
#  ('role', 'NN'),
#  ('shall', 'MD'),
#  ('help', 'VB'),
#  ('you', 'PRP'),
#  ('grow', 'VB'),
#  ('in', 'IN'),
#  ('following', 'VBG'),
#  ('areas', 'NNS'),
#  ('•Big', 'NNP'),
#  ('Technology', 'NNP'),
#  ('based', 'VBN'),
#  ('Analytics', 'NNP'),
#  ('•Introduce', 'NNP'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('and', 'CC'),
#  ('guide', 'VB'),
#  ('you', 'PRP'),
#  ('on', 'IN'),
#  ('cutting', 'VBG'),
#  ('edge', 'NN'),
#  ('Machine', 'NNP'),
#  ('Learning', 'NNP'),
#  ('techniques', 'NNS'),
#  ('•Encourage', 'VBP'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('bring', 'VB'),
#  ('in', 'IN'),
#  ('new', 'JJ'),
#  ('ideas', 'NNS'),
#  ('and', 'CC'),
#  ('provide', 'VB'),
#  ('you', 'PRP'),
#  ('means', 'VBZ'),
#  ('to', 'TO'),
#  ('them', 'PRP'),
#  ('to', 'TO'),
#  ('fulfill', 'VB'),
#  ('project', 'NN'),
#  ('needs', 'VBZ'),
#  ('Responsibilities', 'NNPS'),
#  ('The', 'DT'),
#  ('key', 'JJ'),
#  ('responsibility', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('data', 'NNS'),
#  ('engineer', 'NN'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('ingest', 'VB'),
#  ('structured', 'VBN'),
#  ('semi', 'RB'),
#  ('structured', 'VBN'),
#  ('and', 'CC'),
#  ('unstructured', 'VBN'),
#  ('data', 'NNS'),
#  ('from', 'IN'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('whole', 'JJ'),
#  ('organization', 'NN'),
#  ('within', 'IN'),
#  ('planned', 'VBN'),
#  ('timeframes', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('team', 'NN'),
#  ('of', 'IN'),
#  ('data', 'NNS'),
#  ('scientists', 'NNS'),
#  ('to', 'TO'),
#  ('analyze', 'VB'),
#  ('build', 'JJ'),
#  ('models', 'NNS'),
#  ('and', 'CC'),
#  ('solutions', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('different', 'JJ'),
#  ('businesses', 'NNS'),
#  ('As', 'IN'),
#  ('such', 'JJ'),
#  ('the', 'DT'),
#  ('data', 'NNS'),
#  ('engineer', 'NN'),
#  ('will', 'MD'),
#  ('work', 'VB'),
#  ('with', 'IN'),
#  ('Stakeholders', 'NNP'),
#  ('Business', 'NNP'),
#  ('Users', 'NNP'),
#  ('and', 'CC'),
#  ('Data', 'NNP'),
#  ('Scientists', 'NNS'),
#  ('to', 'TO'),
#  ('understand', 'VB'),
#  ('the', 'DT'),
#  ('business', 'NN'),
#  ('goals', 'NNS'),
#  ('and', 'CC'),
#  ('requirements', 'NNS'),
#  ('and', 'CC'),
#  ('translate', 'VB'),
#  ('them', 'PRP'),
#  ('into', 'IN'),
#  ('data', 'NN'),
#  ('requirements', 'NNS'),
#  ('The', 'DT'),
#  ('engineer', 'NN'),
#  ('will', 'MD'),
#  ('design', 'VB'),
#  ('and', 'CC'),
#  ('build', 'VB'),
#  ('efficient', 'JJ'),
#  ('data', 'NNS'),
#  ('logic', 'NN'),
#  ('Databases', 'NNP'),
#  ('cloud', 'NN'),
#  ('systems', 'NNS'),
#  ('Big', 'NNP'),
#  ('Data', 'NNP'),
#  ('Restful', 'NNP'),
#  ('APIs', 'NNP'),
#  ('etc', 'VBZ'),
#  ('The', 'DT'),
#  ('role', 'NN'),
#  ('also', 'RB'),
#  ('involves', 'VBZ'),
#  ('architecting', 'VBG'),
#  ('and', 'CC'),
#  ('developing', 'VBG'),
#  ('end', 'NN'),
#  ('to', 'TO'),
#  ('end', 'VB'),
#  ('data', 'NNS'),
#  ('pipelines', 'NNS'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('solve', 'VB'),
#  ('data', 'NNS'),
#  ('science', 'NN'),
#  ('problems', 'NNS'),
#  ('while', 'IN'),
#  ('also', 'RB'),
#  ('engaging', 'VBG'),
#  ('in', 'IN'),
#  ('overall', 'JJ'),
#  ('project', 'NN'),
#  ('development', 'NN'),
#  ('activities', 'NNS'),
#  ('What', 'WP'),
#  ('We', 'PRP'),
#  ('re', 'VBP'),
#  ('Looking', 'VBG'),
#  ('For', 'IN'),
#  ('Basic', 'NNP'),
#  ('Qualifications', 'NNP'),
#  ('•Bachelor', 'NNP'),
#  ('degree', 'NN'),
#  ('in', 'IN'),
#  ('engineering', 'NN'),
#  ('•Minimum', 'NN'),
#  ('of', 'IN'),
#  ('years', 'NNS'),
#  ('of', 'IN'),
#  ('experience', 'NN'),
#  ('in', 'IN'),
#  ('Data', 'NNP'),
#  ('Engineering', 'NNP'),
#  ('•Experience', 'NN'),
#  ('in', 'IN'),
#  ('dealing', 'VBG'),
#  ('with', 'IN'),
#  ('servers', 'NNS'),
#  ('production', 'NN'),
#  ('systems', 'NNS'),
#  ('multiple', 'JJ'),
#  ('environments', 'NNS'),
#  ('and', 'CC'),
#  ('varied', 'JJ'),
#  ('software', 'NN'),
#  ('engineering', 'NN'),
#  ('aspects', 'NNS'),
#  ('•Knowledge', 'NN'),
#  ('of', 'IN'),
#  ('Data', 'NNP'),
#  ('Profiling', 'NNP'),
#  ('and', 'CC'),
#  ('Data', 'NNP'),
#  ('Quality', 'NNP'),
#  ('concepts', 'NNS'),
#  ('and', 'CC'),
#  ('techniques', 'NNS'),
#  ('•Ability', 'NN'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('independently', 'RB'),
#  ('and', 'CC'),
#  ('achieve', 'RB'),
#  ('expected', 'VBN'),
#  ('results', 'NNS'),
#  ('with', 'IN'),
#  ('level', 'JJ'),
#  ('requirements', 'NNS'),
#  ('•Strong', 'JJ'),
#  ('written', 'VBN'),
#  ('verbal', 'JJ'),
#  ('communication', 'NN'),
#  ('•Python', 'NNP'),
#  ('•SQL', 'NNP'),
#  ('•Operability', 'NN'),
#  ('in', 'IN'),
#  ('•ETL', 'NN'),
#  ('Tools', 'NNP'),
#  ('and', 'CC'),
#  ('Data', 'NNP'),
#  ('Warehousing', 'NNP'),
#  ('•Big', 'NNP'),
#  ('Data', 'NNP'),
#  ('atleast', 'RB'),
#  ('Hive', 'NNP'),
#  ('HDFS', 'NNP'),
#  ('Flume', 'NNP'),
#  ('Kafka', 'NNP'),
#  ('NoSQL', 'NNP'),
#  ('etc', 'FW'),
#  ('Cloud', 'NNP'),
#  ('Technologies', 'NNPS'),
#  ('Preferred', 'NNP'),
#  ('Qualifications', 'NNP'),
#  ('•Familiarity', 'NN'),
#  ('with', 'IN'),
#  ('RESTful', 'NNP'),
#  ('APIs', 'NNP'),
#  ('•Initial', 'JJ'),
#  ('exposure', 'NN'),
#  ('to', 'TO'),
#  ('machine', 'NN'),
#  ('learning', 'NN'),
#  ('is', 'VBZ'),
#  ('good', 'JJ'),
#  ('to', 'TO'),
#  ('have', 'VB')]

# %%
dfObj = pd.DataFrame(merged) 
dfObj.columns = ['Token', 'POS']
# Out:
#               Token   POS
# 0               The    DT
# 1              Team    NN
# 2                He   PRP
# 3                is   VBZ
# 4       responsible    JJ
# 5               for    IN
# 6         executing   VBG
# 7              Data   NNP
# 8           Science   NNP
# 9          projects   NNS
# 10              end   VBP
# 11               to    TO
# 12              end    VB
# 13              The    DT
# 14          project    NN
# 15             list    NN
# 16         includes   VBZ
# 17              but    CC
# 18               is   VBZ
# 19              not    RB
# 20          limited   VBN
# 21               to    TO
# 22   Recommendation   NNP
# 23          Engines   NNP
# 24              NLP   NNP
# 25            Based   VBD
# 26      Classifiers   NNP
# 27          Ratings   NNP
# 28       Prediction   NNP
# 29             Bond   NNP
# ..              ...   ...
# 303           Tools   NNP
# 304             and    CC
# 305            Data   NNP
# 306     Warehousing   NNP
# 307            •Big   NNP
# 308            Data   NNP
# 309         atleast    RB
# 310            Hive   NNP
# 311            HDFS   NNP
# 312           Flume   NNP
# 313           Kafka   NNP
# 314           NoSQL   NNP
# 315             etc    FW
# 316           Cloud   NNP
# 317    Technologies  NNPS
# 318       Preferred   NNP
# 319  Qualifications   NNP
# 320    •Familiarity    NN
# 321            with    IN
# 322         RESTful   NNP
# 323            APIs   NNP
# 324        •Initial    JJ
# 325        exposure    NN
# 326              to    TO
# 327         machine    NN
# 328        learning    NN
# 329              is   VBZ
# 330            good    JJ
# 331              to    TO
# 332            have    VB
#
# [333 rows x 2 columns]

# %%
dfObj_filtered = dfObj[(dfObj.POS == 'NN')| (dfObj.POS == 'NNP')| (dfObj.POS == 'PRP')]

# %%
df_cd = pd.merge(dfObj_filtered, gender_score, how='inner', on = 'Token')
df_cd
# Out:
#    Token  POS      Gender  Score
# 0     He  PRP  Masculine       1
# 1     it  PRP      Neuter      0
# 2    you  PRP      Neuter      0
# 3    you  PRP      Neuter      0
# 4    you  PRP      Neuter      0
# 5    you  PRP      Neuter      0
# 6    you  PRP      Neuter      0
# 7    you  PRP      Neuter      0
# 8    You  PRP      Neuter      0
# 9   them  PRP      Neuter      0
# 10  them  PRP      Neuter      0

# %%
Total = df_cd['Score'].sum()
if Total > 0:
    print("Job Description is Gender Biased, Please check.")
# Out:
# Job Description is Gender Biased, Please check.
